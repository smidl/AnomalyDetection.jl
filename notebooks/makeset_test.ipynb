# %%
push!(LOAD_PATH, "../src/")
# Out:
# 3-element Array{Any,1}:
#  "/home/vit/anaconda3/local/share/julia/site/v0.6"
#  "/home/vit/anaconda3/share/julia/site/v0.6"
#  "../src/"

# %%
using AnomalyDetection
using StatsBase
using PyPlot

# %%
# set the path to Loda data
master_path = "../../../data/Loda/public/datasets/numerical"
# Out:
# "../../../data/Loda/public/datasets/numerical"

# %%
# load all the Loda data into one dictionary
data = AnomalyDetection.loaddata(master_path)
# Out:
# Dict{String,AnomalyDetection.Basicset} with 38 entries:
#   "breast-cancer-wisconsin" => AnomalyDetection.Basicset([13.54 13.08 … 11.2 7.…
#   "miniboone"               => AnomalyDetection.Basicset([4.87844 6.45217 … 5.4…
#   "haberman"                => AnomalyDetection.Basicset([30.0 30.0 … 76.0 77.0…
#   "blood-transfusion"       => AnomalyDetection.Basicset([1.0 4.0 … 39.0 72.0; …
#   "ecoli"                   => AnomalyDetection.Basicset([0.49 0.07 … 0.67 0.68…
#   "madelon"                 => AnomalyDetection.Basicset([485.0 483.0 … 475.0 4…
#   "statlog-satimage"        => AnomalyDetection.Basicset([92.0 84.0 … 60.0 64.0…
#   "parkinsons"              => AnomalyDetection.Basicset([119.992 122.4 … 148.4…
#   "abalone"                 => AnomalyDetection.Basicset([0.0 0.0 … 1.0 0.0; 0.…
#   "iris"                    => AnomalyDetection.Basicset([5.1 4.9 … 6.2 5.9; 3.…
#   "yeast"                   => AnomalyDetection.Basicset([0.58 0.43 … 0.47 0.43…
#   "pendigits"               => AnomalyDetection.Basicset([95.0 68.0 … 49.0 0.0;…
#   "synthetic-control-chart" => AnomalyDetection.Basicset([28.7812 24.8923 … 34.…
#   "vertebral-column"        => AnomalyDetection.Basicset([38.51 54.92 … 45.25 3…
#   "wine"                    => AnomalyDetection.Basicset([14.23 13.2 … 13.17 14…
#   "statlog-segment"         => AnomalyDetection.Basicset([140.0 188.0 … 79.0 16…
#   "gisette"                 => AnomalyDetection.Basicset([0.0 0.0 … 0.0 0.0; 0.…
#   "musk-2"                  => AnomalyDetection.Basicset([114.0 112.0 … 51.0 51…
#   "pima-indians"            => AnomalyDetection.Basicset([1.0 1.0 … 5.0 1.0; 85…
#   "ionosphere"              => AnomalyDetection.Basicset([1.0 1.0 … 1.0 1.0; 0.…
#   "persistant-connection"   => AnomalyDetection.Basicset([-0.31677 -0.31677 … -…
#   "waveform-2"              => AnomalyDetection.Basicset([-0.69 -0.12 … -0.4 0.…
#   "magic-telescope"         => AnomalyDetection.Basicset([28.7967 31.6036 … 56.…
#   "url"                     => AnomalyDetection.Basicset(Array{Float64}(0,0), A…
#   "breast-tissue"           => AnomalyDetection.Basicset([524.794 330.0 … 1647.…
#   ⋮                         => ⋮

# %%
# does it cluster well?
#testset = AnomalyDetection.Basicset(joinpath(master_path, "iris"))
testset = data["iris"]
train, test, clusterdness = AnomalyDetection.makeset(testset, 0.8, "easy", 0.05, "high")
scatter3D(train.data[1,1:80], train.data[2,1:80], train.data[3,1:80])
scatter3D(train.data[1,81:end], train.data[2,81:end], train.data[3,81:end])
title("high clusterdness = $(clusterdness)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf42050748>)
# PyObject Text(0.5,0.92,'high clusterdness = 8.140187297695906')

# %%
train, test, clusterdness = AnomalyDetection.makeset(testset, 0.8, "easy", 0.05, "low")
scatter3D(train.data[1,1:80], train.data[2,1:80], train.data[3,1:80])
scatter3D(train.data[1,81:end], train.data[2,81:end], train.data[3,81:end])
title("low clusterdness = $(clusterdness)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf255a2978>)
# PyObject Text(0.5,0.92,'low clusterdness = 2.6005491350120233')
